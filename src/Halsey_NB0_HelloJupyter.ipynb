# %% [markdown]
# Notebook 0: Hello, Jupyter!
# ===========================
#
# ## Goals for learning
# In this assignment, we will:
#
# 1) Ensure that our accounts and credentials on the CS department machines are set up.
# 2) Become comfortable in the Jupyter Notebook environment.
# 3) Learn the procedure for submitting assignments in this course.
#
# ## Instructions
# * Read through the notebook.
# * Answer any plain text questions (replace cell content, "YOUR RESPONSE HERE", with your response).
# * Insert your code within the code blocks marked with the comments "# START your code here" and "# STOP your code here".
# * Run all cells to make sure your code works and you see reasonable results.
#
# ## Submission details
# * Due: 11:59pm Monday 9/1/2025
# * Weight: 2 points
# * [Submission instructions](https://www.cs.oswego.edu/~agraci2/csc461/submission_instructions.html)

# %% [markdown]
# About Jupyter
# -------------
# [Project Jupyter](https://jupyter.org/) is a non-profit, open-source project that supports interactive data science and scientific computing.
#
# * __JupyterLab__: a "web-based interactive development environment for notebooks, code, and data". If you would like to run your notebooks locally, there is excellent [installation documentation](https://jupyter.org/install) available.
# * __JupyterHub__: a "multi-user version of the notebook designed for companies, classrooms and research labs." The CS department at SUNY Oswego has an instance of JupyterHub running at [https://indigo.cs.oswego.edu/jupyter](https://indigo.cs.oswego.edu/jupyter). You can use your CS credentials to log in.
#
# About Python
# ------------
# In this course, we will be using the [Python](https://www.python.org/) programming language (version 3) for code examples and assignments.
#
# If you do not have experience with Python, don't worry! We will start with some simple tasks that will allow you to gain familiarity with it.
#
# In the mean time, if you would like to learn some basic Python, there are many free resources and tutorials available online to get you started. For example: [https://docs.python.org/3/tutorial/index.html](https://docs.python.org/3/tutorial/index.html)
#
# About "Kernels"
# ---------------
# >[Kernels are programming language specific processes that run independently and
# >interact with the Jupyter Applications and their user interfaces.](https://docs.jupyter.org/en/latest/projects/kernels.html#kernels-langs)
#
# Jupyter notebooks allow you to write and execute code directly in your browser when you use a "code" type cell, such as the one below. The programming language that is executed is determined by the kernel that you have selected for your notebook (see the upper right-hand corner for an indicator of which kernel is selected).
#
# Although there are kernels available to support [many languages](https://github.com/jupyter/jupyter/wiki/Jupyter-kernels), we will be using the default IPython kernel in this course.
#
# To run a cell, select it, and then click the "Run the selected cells and advance" button on the toolbar above:
#
# ![run](https://www.cs.oswego.edu/~agraci2/csc461/notebook_images/run.png "Run the selected cells and advance button symbol")

# %%
'''
The following lines of code will show you the exact version of the 
IPython kernel that is running
'''
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=13, micro=1, releaselevel='final', serial=0)

# %% [markdown]
# A Gentle Introduction to Python
# --------------------------------
# Below, write a simple Python3 program to display the phrase "Hello, Jupyter!".
#
# If you have never used Python3 before, you may find the following resource helpful: [https://docs.python.org/3/tutorial/introduction.html#text](https://docs.python.org/3/tutorial/introduction.html#text)

# %%
# START your code here
print("Hello, Jupyter!")
# STOP your code here
# Out:
# Hello, Jupyter!

# %% [markdown]
# ##### <b>Question:</b> Have you ever used ML before? If so, what did you use it for?

# %% [raw]
# Yes, I've used Random Forest and XGBoost/Gradient Boost to analyze significant variables at my Data Science internship. I've also learned a little bit about kNN and k-means clustering in a Data Analytics course.

# %% [markdown]
# Make sure to save your changes before submitting, using the "Save and create checkpoint" button on the toolbar above:
#
# ![save_button](https://www.cs.oswego.edu/~agraci2/csc461/notebook_images/save.png "Save and create checkpoint button symbol")

# %% [markdown]
# ##### Congratulations, you have reached the end of this notebook!
